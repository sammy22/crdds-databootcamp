# %% [markdown]
# <a href="https://colab.research.google.com/github/sammy22/crdds-databootcamp/blob/master/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Set 1 - KNN
# ## CSCI 5622 - Spring 2020
#
# For today's assignment, we will be implementing our own K-Nearest Neighbors (KNN) algorithm.
#
# *But Professor Quigley, hasn't someone else already written KNN before?*
#
# Yes, you are not the first to implement KNN, or basically any algorithm we'll work with in this class. But
# 1. I'll know that you know what's really going on
# 2. You'll know you can do it, because
#     1. someday you might have to implement some machine learning algorithm from scratch - maybe for a new platform (do you need to run python on your SmartToaster just to get it to learn how users like their toast?), maybe because you want to tweak the algorithm (there's always a better approach...),
#     2. maybe because you're working on something important, and you need to control exactly what's on there (should you really be running anaconda on your secret spy plane?).
#
# That said - we're not going to implement *everything*. We'll start by importing a few helper functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import sklearn.neighbors
import sklearn.datasets
import sklearn.metrics

# %% [markdown]
# *Wait a minute - didn't we just import Scikit-learn (sklearn)? The package with baked-in machine learning tools?*
#
# Yes - but it also has a ton of helper functions, including a dataset we'll be using later. But first, let's also create a dataset to play with and start working to build out our own classifier.

# %%
X, y = sklearn.datasets.make_moons(n_samples=200, noise=0.19, random_state=42)
X_train, y_train = X[:100], y[:100]
X_test, y_test = X[100:], y[100:]
plt.title("Two moon clusters (Full dataset)")
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
counts = {}
for l in y:
  counts[l] = counts.get(l,0) + 1
print(counts)
print(dict(zip(sorted(counts.keys()), range(len(counts)))))
print(dict(zip(range(len(counts)), sorted(counts.keys()))))
# Out:
# {0: 100, 1: 100}
# {0: 0, 1: 1}
# {0: 0, 1: 1}

# %% [markdown]
# We have data!
#
# Now, let's set up a KNNClassifier class.
#
# The KNNClassifier class will have similar design to the K-Nearest Neighbors classifier class from *scikit-learn*:
# - Initialize the classifier with corresponding parameters (number of neighbors k)
# - Fit the classifier using the training data
# - Predict the class of new points `X_test`
#
# We've written out a lot of the structure for you so it will be consistent and we can use / reuse it, and you can focus on the "important" stuff that actually relates to the machine learning itself.

# %%
class KNNClassifier:

    def __init__(self, k = 5):
        """
        Initialize our custom KNN classifier
        PARAMETERS

        k - the number of nearest neighbors to consider for classification
        """
        self._k = k
        self._model = None
        self._y = None
        self.label_to_index = None
        self.index_to_label = None
        self.counts = 0

    def fit(self, features, labels):
        """
        
        :param features: 2-D np.array of shape (number training samples, features dimension)
        :param labels: 1-D np.array of shape (number training samples,)
        :return: self
        """
        
        self._model = sklearn.neighbors.BallTree(features, metric='euclidean')
        self._y = labels
        self.counts = self.get_counts()
        # Should be used to map the classes to {0,1,..C-1} where C is the number of classes
        self.label_to_index = dict(zip(sorted(self.counts.keys()), range(len(self.counts))))
        self.index_to_label = dict(zip(range(len(self.counts)), sorted(self.counts.keys())))
        return self

    def get_counts(self):
        """
        Creates a dictionary storing the count of elements of each class
        :return: dict where the keys are the classes and values are the counts
        """

        counts = dict()
        #BEGIN Workspace 1.1
        #TODO: Modify and/or add to counts so that it returns a count of each answer class found in y
        #END Workspace 1.1
        for l in self._y:
          counts[l] = counts.get(l,0) + 1
        return counts

    def majority_vote(self, indices):
        """
        Given indices, report the majority label of those points.
        FOR A TIE, report the most common label in the data set.
        :param indices: indices of training neighbors of shape (M, k) where k the classifier parameter
        :return: The majority label for each set of indices, shape (M,)
        """

        labels = np.zeros(len(indices)) # REPLACE
        
        from scipy import stats
        for i,index in enumerate(indices):
          labels[i] = stats.mode(self._y[index])[0]
        
        #BEGIN Workspace 1.2
        # TODO: Determine majority, assign it to label
        #END Workspace 1.2
        return labels

    def predict(self, points):
        """
        Given new data points, classify then according to the training data provided in fit and number of neighbors k
        :param point: feature vectors (num_points, num_features)
        :return: 1-D np.array of predicted classes of shape (num_points,)
        """

        # answer = 0
        dist, ind = self._model.query(points,k=self._k) 
        answer = self.majority_vote(ind)
        #BEGIN Workspace 1.3
        #TODO: perform classification of points here
        #HINT: use the majority function created above
        #HINT: use the euclidean distance discussed in lecture to find nearest neighbors
        
        #END Workspace 1.3
        return answer

    def confusion_matrix(self, features_test, labels_test):
        """
        Generate the confusion matrix for the given test data
        :param features_test: an np.array of feature vectors of test points, shape (N, n_features)
        :param labels_test: he corresponding correct classes of our test set, shape (N,)
        :return: an C*C np.array of counts, where C is the number of classes in our classifier
        """
        C = len(self.counts)
        c_matrix = np.zeros([C,C]) # REPLACE
        
        #BEGIN Workspace 1.4
        #TODO: Run classification for the test set, compare to test answers, and add counts to matrix
        predicted_labels = self.predict(features_test)
        
        for p in range(len(predicted_labels)):
          
          c_matrix[int(labels_test[p])][int(predicted_labels[p])] +=1
        return c_matrix

    def accuracy(self, features_test, labels_test):
        """
        Generate an accuracy score for the classifier based on the confusion matrix
        PARAMETERS
        C - an np.array of counts
        RETURN
        score - an accuracy score
        """
        # score = 0
        #BEGIN Workspace 1.5
        #TODO: Compute accuracy of the classification of X_test
        c_matrix = self.confusion_matrix(features_test,labels_test)
        score = np.trace(c_matrix)/np.sum(c_matrix)
        #END Workspace 1.5
        return score

# %% [markdown]
# *But professor, this code isn't complete!*
#
# ### Problem 1: Complete our KNN Classifier - 25 Points
#
# 1.1 - Complete the `get_counts` function to return the count of each class found in the training set (5 points)
#
# 1.2 - Complete the `majority_vote` function to determine the majority class of a series of neighbors (5 points)
#
# 1.3 - Complete the `predict` function to capture the predicted class of a new datapoint (5 points)
#
#  - HINT: Use the BallTree documentation to determine how to retrieve neighbors from the model (https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.BallTree.html#sklearn.neighbors.BallTree)
#
# 1.4 - Complete the `confusion_matrix` function to reveal the results of classification (5 points)
#
# 1.5 - Complete the `accuracy` function to get accuracy of the classifier based on a given test data (5 points)
#
# Below, we'll be using our KNNClassifier (sent in as "model") to show how we would predict any points in space given the input data.

# %%
def show_decision_surface(model):
    """
    Helper function to visualize the decision surface of model
    :param model: Initialized KNNClassifier
    :return: None
    """
    x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
    y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
    x_grid = np.arange(x_min, x_max, 0.1)
    y_grid = np.arange(y_min, y_max, 0.1)
    xx, yy = np.meshgrid(x_grid, y_grid)
    r1, r2 = xx.reshape(-1,1), yy.reshape(-1,1)
    grid = np.hstack((r1,r2))
    y_hat = model.predict(grid)
    zz = y_hat.reshape(xx.shape)
    plt.contourf(xx, yy, zz, cmap='PiYG')
    plt.scatter(X[:,0], X[:,1], c=y)
    plt.show()

# %% [markdown]
# 1.6. Try different values of k and report their accuracies and confusion matrices on the test set. Make sure to keep `random_state=42` so that the reported values don't change when code is re-run (5 points)

# %%
#BEGIN Workspace 1.6
#TODO: Try different Ks        
kk = 3
model = KNNClassifier(k=kk)
model = model.fit(X_train, y_train)
plt.title("Training decision surface for k = {}".format(kk))
show_decision_surface(model)
#END Workspace 1.6

# %%
# Code for 1.6

for kk in range(1,10):
  model = KNNClassifier(k=kk)
  model = model.fit(X_train, y_train)
  score = model.accuracy(X_test,y_test)
  print(score)
# Out:
# 0.92
# 0.96
# 0.96
# 0.96
# 0.97
# 0.96
# 0.97
# 0.97
# 0.97

# %% [markdown]
# #### Write up for 1.6 here

# %% [markdown]
# ### Bonus (for the avid machine learner) (5 Points)
# 1.7. For which value of $k$ is the classifier consistent? (Only worry about this question within our `random_state=42` constraint)
#
# 1.8. Edit your `KNNClassifier` so that it's consistent for all $k$ (This solution should work beyond our `random_state=42` constraint, but retain the constraint when submitting your code above)
#
# For a definition of a consistent classifier, refer to [Consistent Classification, Firm and Soft by Barum](https://proceedings.neurips.cc/paper/1996/file/7bb060764a818184ebb1cc0d43d382aa-Paper.pdf) (The answer is found in the abstract and introduction sections of the paper)

# %% [markdown]
# #### Write up for the bonus

# %% [markdown]
# ***
# OK - now we've demonstrated that our KNN classifier works, let's think about our problem space!
#
# ## Our Dataset - Identifying Digits from Images
#
# It's a pretty common problem - just imagine working at the post office, and you're handed a hand-written check,
# and you have to identify exactly what it says.
# Did they pay 500 or 600 dollars? Is the letter going to 80309 (campus) or 30309 (Atlanta)?
#
# Let's be a little smart about this - let's up some classes and helper functions to help us out.
#
# ### Problem 2: Implement KNN on Digits dataset - 25 Points
#
# 2.1 **Randomly** divide our digit dataset into training and testing sets (10 Points)
#
# 2.2 Report the number of examples in training and testing, as well as measuring then number of pixels in each image (5 points)
#
# 2.3 Create a confusion matrix of our classifier for K = 5 (10 points) *HINT: Doing this may cause you to catch mistakes in your classifier. Go fix those!*

# %%
import math
class Numbers:
    def __init__(self):
        #load data from sklearn
        
        data = sklearn.datasets.load_digits()
        features = data["data"]
        self.labels = data["target"]
        self.features = features.reshape(features.shape[0], -1)
        
        # BEGIN Workspace 2.1  
        self.train_x, self.test_x, self.train_y, self.test_y = sklearn.model_selection.train_test_split(self.features, self.labels, test_size=0.2, random_state=42)      
        # row,col = self.features.shape
        # self.train_x = self.features[:math.ceil(0.8*row)]  # A 2D np.array of training examples, REPLACE
        # self.train_y = self.labels[:math.ceil(0.8*row)] # A 1D np.array of training answers, REPLACE
        # self.test_x = self.features[math.ceil(0.8*row):] # A 2D np.array of testing examples, REPLACE
        # self.test_y = self.features[math.ceil(0.8*row):] # A 1D np.array of testing answers, REPLACE
        self.classifier = KNNClassifier(k=5) # KNNClassifier, REPLACE
        
        # TODO: - Divide our dataset into Train and Test datasets (80/20 split),
        #        replacing the variables above
        #       - Initialize the classifier
        #END Workspace 2.1
        
    def report(self):
        """
        Report information about the dataset using the print() function
        """
        #BEGIN Workspace 2.2
        #TODO: Create printouts for reporting the size of each set and the size of each datapoint
        
        print(f"Size of training set of features {self.train_x.shape}")
        print(f"Size of training set of labels {self.train_y.shape}")
        print(f"Size of test set of features {self.test_x.shape}")
        print(f"Size of test set of features {self.test_y.shape}")
        
        for i,f in enumerate(self.train_x) : 
          print(f"Number of pixels in datapoint {i} is {np.unique(f).shape[0]}")
        #END Workspace 2.2
    

    def classify(self):
        """
        Fits classifier using the training data and generate a confusion matrix for the test data
        then return the confusion matrix
        """
        #BEGIN Workspace 2.3.a
        #TODO: Create classifier from training data, generate confusion matrix for test data
        # self.classifier.fit(# TODO)
        #END Workspace 2.3.a
        print(self.test_y.shape)
        print(self.train_y.shape)
        return  self.classifier.fit(self.train_x,self.train_y).confusion_matrix(self.test_x,self.test_y)
           
    def accuracy(self):
        c_matrix = self.classify()
        accuracy = 0
        #BEGIN Workspace 2.3.b
        #TODO: Compute accuracy using confusion matrix
        score = np.trace(c_matrix)/np.sum(c_matrix)
        #END Workspace 2.3.b
        return accuracy

    def view_digit(self, index):
        """
        Display an image of a digit
        PARAMETERS
        digitImage - a data object from the dataset
        """
        #TODO: process digit_image to matrix "image"
        digit_image = self.features[index]
        image = digit_image.reshape(8, -1)
        print("Image for digit {}".format(self.labels[index]))
        plt.matshow(image)
        plt.show()
    
    @staticmethod
    def display_confusion(c_matrix):
        fig, ax = plt.subplots()
        ax.matshow(c_matrix, cmap=plt.cm.Blues)
        for i in range(c_matrix.shape[0]):
            for j in range(c_matrix.shape[0]):
                ax.text(i, j, str(c_matrix[j,i]), va='center', ha='center')
        plt.show()

# %%
numbers = Numbers()
numbers.report()
numbers.view_digit(10)
Numbers.display_confusion(numbers.classify())
# Out:
# Size of training set of features (1437, 64)
# Size of training set of labels (1437,)
# Size of test set of features (360, 64)
# Size of test set of features (360,)
# Number of pixels in datapoint 0 is 13
# Number of pixels in datapoint 1 is 14
# Number of pixels in datapoint 2 is 15
# Number of pixels in datapoint 3 is 15
# Number of pixels in datapoint 4 is 16
# Number of pixels in datapoint 5 is 16
# Number of pixels in datapoint 6 is 13
# Number of pixels in datapoint 7 is 16
# Number of pixels in datapoint 8 is 15
# Number of pixels in datapoint 9 is 11
# Number of pixels in datapoint 10 is 15
# Number of pixels in datapoint 11 is 15
# Number of pixels in datapoint 12 is 14
# Number of pixels in datapoint 13 is 14
# Number of pixels in datapoint 14 is 14
# Number of pixels in datapoint 15 is 15
# Number of pixels in datapoint 16 is 14
# Number of pixels in datapoint 17 is 12
# Number of pixels in datapoint 18 is 15
# Number of pixels in datapoint 19 is 15
# Number of pixels in datapoint 20 is 13
# Number of pixels in datapoint 21 is 16
# Number of pixels in datapoint 22 is 16
# Number of pixels in datapoint 23 is 16
# Number of pixels in datapoint 24 is 16
# Number of pixels in datapoint 25 is 17
# Number of pixels in datapoint 26 is 15
# Number of pixels in datapoint 27 is 14
# Number of pixels in datapoint 28 is 15
# Number of pixels in datapoint 29 is 13
# Number of pixels in datapoint 30 is 14
# Number of pixels in datapoint 31 is 17
# Number of pixels in datapoint 32 is 16
# Number of pixels in datapoint 33 is 11
# Number of pixels in datapoint 34 is 15
# Number of pixels in datapoint 35 is 17
# Number of pixels in datapoint 36 is 13
# Number of pixels in datapoint 37 is 15
# Number of pixels in datapoint 38 is 12
# Number of pixels in datapoint 39 is 12
# Number of pixels in datapoint 40 is 15
# Number of pixels in datapoint 41 is 16
# Number of pixels in datapoint 42 is 15
# Number of pixels in datapoint 43 is 14
# Number of pixels in datapoint 44 is 15
# Number of pixels in datapoint 45 is 14
# Number of pixels in datapoint 46 is 16
# Number of pixels in datapoint 47 is 15
# Number of pixels in datapoint 48 is 15
# Number of pixels in datapoint 49 is 12
# Number of pixels in datapoint 50 is 16
# Number of pixels in datapoint 51 is 16
# Number of pixels in datapoint 52 is 15
# Number of pixels in datapoint 53 is 14
# Number of pixels in datapoint 54 is 14
# Number of pixels in datapoint 55 is 16
# Number of pixels in datapoint 56 is 15
# Number of pixels in datapoint 57 is 15
# Number of pixels in datapoint 58 is 14
# Number of pixels in datapoint 59 is 15
# Number of pixels in datapoint 60 is 16
# Number of pixels in datapoint 61 is 16
# Number of pixels in datapoint 62 is 15
# Number of pixels in datapoint 63 is 14
# Number of pixels in datapoint 64 is 13
# Number of pixels in datapoint 65 is 14
# Number of pixels in datapoint 66 is 13
# Number of pixels in datapoint 67 is 16
# Number of pixels in datapoint 68 is 14
# Number of pixels in datapoint 69 is 13
# Number of pixels in datapoint 70 is 15
# Number of pixels in datapoint 71 is 15
# Number of pixels in datapoint 72 is 14
# Number of pixels in datapoint 73 is 13
# Number of pixels in datapoint 74 is 16
# Number of pixels in datapoint 75 is 15
# Number of pixels in datapoint 76 is 15
# Number of pixels in datapoint 77 is 14
# Number of pixels in datapoint 78 is 14
# Number of pixels in datapoint 79 is 15
# Number of pixels in datapoint 80 is 11
# Number of pixels in datapoint 81 is 15
# Number of pixels in datapoint 82 is 16
# Number of pixels in datapoint 83 is 15
# Number of pixels in datapoint 84 is 14
# Number of pixels in datapoint 85 is 13
# Number of pixels in datapoint 86 is 15
# Number of pixels in datapoint 87 is 16
# Number of pixels in datapoint 88 is 15
# Number of pixels in datapoint 89 is 14
# Number of pixels in datapoint 90 is 14
# Number of pixels in datapoint 91 is 15
# Number of pixels in datapoint 92 is 16
# Number of pixels in datapoint 93 is 16
# Number of pixels in datapoint 94 is 14
# Number of pixels in datapoint 95 is 14
# Number of pixels in datapoint 96 is 14
# Number of pixels in datapoint 97 is 16
# Number of pixels in datapoint 98 is 16
# Number of pixels in datapoint 99 is 12
# Number of pixels in datapoint 100 is 16
# Number of pixels in datapoint 101 is 15
# Number of pixels in datapoint 102 is 15
# Number of pixels in datapoint 103 is 14
# Number of pixels in datapoint 104 is 14
# Number of pixels in datapoint 105 is 15
# Number of pixels in datapoint 106 is 16
# Number of pixels in datapoint 107 is 16
# Number of pixels in datapoint 108 is 16
# Number of pixels in datapoint 109 is 14
# Number of pixels in datapoint 110 is 14
# Number of pixels in datapoint 111 is 14
# Number of pixels in datapoint 112 is 15
# Number of pixels in datapoint 113 is 14
# Number of pixels in datapoint 114 is 13
# Number of pixels in datapoint 115 is 12
# Number of pixels in datapoint 116 is 12
# Number of pixels in datapoint 117 is 16
# Number of pixels in datapoint 118 is 16
# Number of pixels in datapoint 119 is 13
# Number of pixels in datapoint 120 is 13
# Number of pixels in datapoint 121 is 15
# Number of pixels in datapoint 122 is 16
# Number of pixels in datapoint 123 is 14
# Number of pixels in datapoint 124 is 15
# Number of pixels in datapoint 125 is 15
# Number of pixels in datapoint 126 is 13
# Number of pixels in datapoint 127 is 16
# Number of pixels in datapoint 128 is 15
# Number of pixels in datapoint 129 is 13
# Number of pixels in datapoint 130 is 15
# Number of pixels in datapoint 131 is 11
# Number of pixels in datapoint 132 is 14
# Number of pixels in datapoint 133 is 14
# Number of pixels in datapoint 134 is 14
# Number of pixels in datapoint 135 is 16
# Number of pixels in datapoint 136 is 13
# Number of pixels in datapoint 137 is 13
# Number of pixels in datapoint 138 is 13
# Number of pixels in datapoint 139 is 12
# Number of pixels in datapoint 140 is 14
# Number of pixels in datapoint 141 is 15
# Number of pixels in datapoint 142 is 16
# Number of pixels in datapoint 143 is 14
# Number of pixels in datapoint 144 is 15
# Number of pixels in datapoint 145 is 14
# Number of pixels in datapoint 146 is 12
# Number of pixels in datapoint 147 is 16
# Number of pixels in datapoint 148 is 15
# Number of pixels in datapoint 149 is 14
# Number of pixels in datapoint 150 is 13
# Number of pixels in datapoint 151 is 15
# Number of pixels in datapoint 152 is 17
# Number of pixels in datapoint 153 is 10
# Number of pixels in datapoint 154 is 14
# Number of pixels in datapoint 155 is 15
# Number of pixels in datapoint 156 is 15
# Number of pixels in datapoint 157 is 13
# Number of pixels in datapoint 158 is 15
# Number of pixels in datapoint 159 is 13
# Number of pixels in datapoint 160 is 15
# Number of pixels in datapoint 161 is 13
# Number of pixels in datapoint 162 is 15
# Number of pixels in datapoint 163 is 14
# Number of pixels in datapoint 164 is 15
# Number of pixels in datapoint 165 is 14
# Number of pixels in datapoint 166 is 15
# Number of pixels in datapoint 167 is 12
# Number of pixels in datapoint 168 is 15
# Number of pixels in datapoint 169 is 15
# Number of pixels in datapoint 170 is 16
# Number of pixels in datapoint 171 is 13
# Number of pixels in datapoint 172 is 12
# Number of pixels in datapoint 173 is 13
# Number of pixels in datapoint 174 is 15
# Number of pixels in datapoint 175 is 15
# Number of pixels in datapoint 176 is 14
# Number of pixels in datapoint 177 is 16
# Number of pixels in datapoint 178 is 15
# Number of pixels in datapoint 179 is 15
# Number of pixels in datapoint 180 is 15
# Number of pixels in datapoint 181 is 13
# Number of pixels in datapoint 182 is 15
# Number of pixels in datapoint 183 is 14
# Number of pixels in datapoint 184 is 16
# Number of pixels in datapoint 185 is 14
# Number of pixels in datapoint 186 is 15
# Number of pixels in datapoint 187 is 15
# Number of pixels in datapoint 188 is 15
# Number of pixels in datapoint 189 is 14
# Number of pixels in datapoint 190 is 15
# Number of pixels in datapoint 191 is 14
# Number of pixels in datapoint 192 is 15
# Number of pixels in datapoint 193 is 15
# Number of pixels in datapoint 194 is 15
# Number of pixels in datapoint 195 is 9
# Number of pixels in datapoint 196 is 16
# Number of pixels in datapoint 197 is 17
# Number of pixels in datapoint 198 is 14
# Number of pixels in datapoint 199 is 13
# Number of pixels in datapoint 200 is 16
# Number of pixels in datapoint 201 is 16
# Number of pixels in datapoint 202 is 13
# Number of pixels in datapoint 203 is 16
# Number of pixels in datapoint 204 is 15
# Number of pixels in datapoint 205 is 13
# Number of pixels in datapoint 206 is 12
# Number of pixels in datapoint 207 is 15
# Number of pixels in datapoint 208 is 14
# Number of pixels in datapoint 209 is 16
# Number of pixels in datapoint 210 is 14
# Number of pixels in datapoint 211 is 15
# Number of pixels in datapoint 212 is 11
# Number of pixels in datapoint 213 is 14
# Number of pixels in datapoint 214 is 14
# Number of pixels in datapoint 215 is 14
# Number of pixels in datapoint 216 is 14
# Number of pixels in datapoint 217 is 15
# Number of pixels in datapoint 218 is 16
# Number of pixels in datapoint 219 is 16
# Number of pixels in datapoint 220 is 12
# Number of pixels in datapoint 221 is 14
# Number of pixels in datapoint 222 is 15
# Number of pixels in datapoint 223 is 14
# Number of pixels in datapoint 224 is 16
# Number of pixels in datapoint 225 is 16
# Number of pixels in datapoint 226 is 15
# Number of pixels in datapoint 227 is 14
# Number of pixels in datapoint 228 is 15
# Number of pixels in datapoint 229 is 14
# Number of pixels in datapoint 230 is 15
# Number of pixels in datapoint 231 is 16
# Number of pixels in datapoint 232 is 16
# Number of pixels in datapoint 233 is 15
# Number of pixels in datapoint 234 is 13
# Number of pixels in datapoint 235 is 12
# Number of pixels in datapoint 236 is 14
# Number of pixels in datapoint 237 is 13
# Number of pixels in datapoint 238 is 14
# Number of pixels in datapoint 239 is 14
# Number of pixels in datapoint 240 is 13
# Number of pixels in datapoint 241 is 16
# Number of pixels in datapoint 242 is 15
# Number of pixels in datapoint 243 is 13
# Number of pixels in datapoint 244 is 14
# Number of pixels in datapoint 245 is 15
# Number of pixels in datapoint 246 is 15
# Number of pixels in datapoint 247 is 12
# Number of pixels in datapoint 248 is 14
# Number of pixels in datapoint 249 is 14
# Number of pixels in datapoint 250 is 14
# Number of pixels in datapoint 251 is 16
# Number of pixels in datapoint 252 is 15
# Number of pixels in datapoint 253 is 14
# Number of pixels in datapoint 254 is 12
# Number of pixels in datapoint 255 is 13
# Number of pixels in datapoint 256 is 15
# Number of pixels in datapoint 257 is 13
# Number of pixels in datapoint 258 is 15
# Number of pixels in datapoint 259 is 14
# Number of pixels in datapoint 260 is 16
# Number of pixels in datapoint 261 is 13
# Number of pixels in datapoint 262 is 14
# Number of pixels in datapoint 263 is 15
# Number of pixels in datapoint 264 is 13
# Number of pixels in datapoint 265 is 14
# Number of pixels in datapoint 266 is 11
# Number of pixels in datapoint 267 is 16
# Number of pixels in datapoint 268 is 14
# Number of pixels in datapoint 269 is 12
# Number of pixels in datapoint 270 is 15
# Number of pixels in datapoint 271 is 15
# Number of pixels in datapoint 272 is 14
# Number of pixels in datapoint 273 is 15
# Number of pixels in datapoint 274 is 14
# Number of pixels in datapoint 275 is 12
# Number of pixels in datapoint 276 is 15
# Number of pixels in datapoint 277 is 14
# Number of pixels in datapoint 278 is 15
# Number of pixels in datapoint 279 is 14
# Number of pixels in datapoint 280 is 14
# Number of pixels in datapoint 281 is 14
# Number of pixels in datapoint 282 is 14
# Number of pixels in datapoint 283 is 14
# Number of pixels in datapoint 284 is 15
# Number of pixels in datapoint 285 is 15
# Number of pixels in datapoint 286 is 15
# Number of pixels in datapoint 287 is 14
# Number of pixels in datapoint 288 is 16
# Number of pixels in datapoint 289 is 11
# Number of pixels in datapoint 290 is 16
# Number of pixels in datapoint 291 is 16
# Number of pixels in datapoint 292 is 7
# Number of pixels in datapoint 293 is 13
# Number of pixels in datapoint 294 is 12
# Number of pixels in datapoint 295 is 11
# Number of pixels in datapoint 296 is 14
# Number of pixels in datapoint 297 is 13
# Number of pixels in datapoint 298 is 16
# Number of pixels in datapoint 299 is 15
# Number of pixels in datapoint 300 is 15
# Number of pixels in datapoint 301 is 14
# Number of pixels in datapoint 302 is 12
# Number of pixels in datapoint 303 is 16
# Number of pixels in datapoint 304 is 13
# Number of pixels in datapoint 305 is 12
# Number of pixels in datapoint 306 is 15
# Number of pixels in datapoint 307 is 13
# Number of pixels in datapoint 308 is 13
# Number of pixels in datapoint 309 is 16
# Number of pixels in datapoint 310 is 17
# Number of pixels in datapoint 311 is 11
# Number of pixels in datapoint 312 is 12
# Number of pixels in datapoint 313 is 16
# Number of pixels in datapoint 314 is 17
# Number of pixels in datapoint 315 is 15
# Number of pixels in datapoint 316 is 13
# Number of pixels in datapoint 317 is 16
# Number of pixels in datapoint 318 is 16
# Number of pixels in datapoint 319 is 15
# Number of pixels in datapoint 320 is 15
# Number of pixels in datapoint 321 is 14
# Number of pixels in datapoint 322 is 15
# Number of pixels in datapoint 323 is 15
# Number of pixels in datapoint 324 is 15
# Number of pixels in datapoint 325 is 15
# Number of pixels in datapoint 326 is 12
# Number of pixels in datapoint 327 is 15
# Number of pixels in datapoint 328 is 15
# Number of pixels in datapoint 329 is 14
# Number of pixels in datapoint 330 is 13
# Number of pixels in datapoint 331 is 12
# Number of pixels in datapoint 332 is 13
# Number of pixels in datapoint 333 is 14
# Number of pixels in datapoint 334 is 14
# Number of pixels in datapoint 335 is 16
# Number of pixels in datapoint 336 is 12
# Number of pixels in datapoint 337 is 13
# Number of pixels in datapoint 338 is 15
# Number of pixels in datapoint 339 is 14
# Number of pixels in datapoint 340 is 15
# Number of pixels in datapoint 341 is 15
# Number of pixels in datapoint 342 is 12
# Number of pixels in datapoint 343 is 16
# Number of pixels in datapoint 344 is 15
# Number of pixels in datapoint 345 is 15
# Number of pixels in datapoint 346 is 13
# Number of pixels in datapoint 347 is 14
# Number of pixels in datapoint 348 is 14
# Number of pixels in datapoint 349 is 9
# Number of pixels in datapoint 350 is 12
# Number of pixels in datapoint 351 is 15
# Number of pixels in datapoint 352 is 15
# Number of pixels in datapoint 353 is 14
# Number of pixels in datapoint 354 is 15
# Number of pixels in datapoint 355 is 15
# Number of pixels in datapoint 356 is 12
# Number of pixels in datapoint 357 is 15
# Number of pixels in datapoint 358 is 14
# Number of pixels in datapoint 359 is 14
# Number of pixels in datapoint 360 is 14
# Number of pixels in datapoint 361 is 15
# Number of pixels in datapoint 362 is 15
# Number of pixels in datapoint 363 is 15
# Number of pixels in datapoint 364 is 15
# Number of pixels in datapoint 365 is 15
# Number of pixels in datapoint 366 is 15
# Number of pixels in datapoint 367 is 13
# Number of pixels in datapoint 368 is 13
# Number of pixels in datapoint 369 is 10
# Number of pixels in datapoint 370 is 16
# Number of pixels in datapoint 371 is 16
# Number of pixels in datapoint 372 is 15
# Number of pixels in datapoint 373 is 14
# Number of pixels in datapoint 374 is 15
# Number of pixels in datapoint 375 is 12
# Number of pixels in datapoint 376 is 16
# Number of pixels in datapoint 377 is 15
# Number of pixels in datapoint 378 is 16
# Number of pixels in datapoint 379 is 14
# Number of pixels in datapoint 380 is 11
# Number of pixels in datapoint 381 is 15
# Number of pixels in datapoint 382 is 15
# Number of pixels in datapoint 383 is 16
# Number of pixels in datapoint 384 is 13
# Number of pixels in datapoint 385 is 15
# Number of pixels in datapoint 386 is 15
# Number of pixels in datapoint 387 is 14
# Number of pixels in datapoint 388 is 15
# Number of pixels in datapoint 389 is 14
# Number of pixels in datapoint 390 is 14
# Number of pixels in datapoint 391 is 15
# Number of pixels in datapoint 392 is 14
# Number of pixels in datapoint 393 is 14
# Number of pixels in datapoint 394 is 15
# Number of pixels in datapoint 395 is 14
# Number of pixels in datapoint 396 is 15
# Number of pixels in datapoint 397 is 16
# Number of pixels in datapoint 398 is 14
# Number of pixels in datapoint 399 is 16
# Number of pixels in datapoint 400 is 15
# Number of pixels in datapoint 401 is 14
# Number of pixels in datapoint 402 is 17
# Number of pixels in datapoint 403 is 14
# Number of pixels in datapoint 404 is 12
# Number of pixels in datapoint 405 is 15
# Number of pixels in datapoint 406 is 16
# Number of pixels in datapoint 407 is 15
# Number of pixels in datapoint 408 is 13
# Number of pixels in datapoint 409 is 15
# Number of pixels in datapoint 410 is 14
# Number of pixels in datapoint 411 is 12
# Number of pixels in datapoint 412 is 15
# Number of pixels in datapoint 413 is 13
# Number of pixels in datapoint 414 is 17
# Number of pixels in datapoint 415 is 17
# Number of pixels in datapoint 416 is 14
# Number of pixels in datapoint 417 is 14
# Number of pixels in datapoint 418 is 15
# Number of pixels in datapoint 419 is 13
# Number of pixels in datapoint 420 is 13
# Number of pixels in datapoint 421 is 15
# Number of pixels in datapoint 422 is 16
# Number of pixels in datapoint 423 is 17
# Number of pixels in datapoint 424 is 13
# Number of pixels in datapoint 425 is 14
# Number of pixels in datapoint 426 is 12
# Number of pixels in datapoint 427 is 16
# Number of pixels in datapoint 428 is 15
# Number of pixels in datapoint 429 is 15
# Number of pixels in datapoint 430 is 13
# Number of pixels in datapoint 431 is 13
# Number of pixels in datapoint 432 is 14
# Number of pixels in datapoint 433 is 16
# Number of pixels in datapoint 434 is 14
# Number of pixels in datapoint 435 is 16
# Number of pixels in datapoint 436 is 16
# Number of pixels in datapoint 437 is 15
# Number of pixels in datapoint 438 is 15
# Number of pixels in datapoint 439 is 15
# Number of pixels in datapoint 440 is 15
# Number of pixels in datapoint 441 is 17
# Number of pixels in datapoint 442 is 15
# Number of pixels in datapoint 443 is 14
# Number of pixels in datapoint 444 is 12
# Number of pixels in datapoint 445 is 15
# Number of pixels in datapoint 446 is 16
# Number of pixels in datapoint 447 is 16
# Number of pixels in datapoint 448 is 14
# Number of pixels in datapoint 449 is 16
# Number of pixels in datapoint 450 is 17
# Number of pixels in datapoint 451 is 12
# Number of pixels in datapoint 452 is 16
# Number of pixels in datapoint 453 is 13
# Number of pixels in datapoint 454 is 16
# Number of pixels in datapoint 455 is 14
# Number of pixels in datapoint 456 is 14
# Number of pixels in datapoint 457 is 13
# Number of pixels in datapoint 458 is 12
# Number of pixels in datapoint 459 is 15
# Number of pixels in datapoint 460 is 15
# Number of pixels in datapoint 461 is 15
# Number of pixels in datapoint 462 is 15
# Number of pixels in datapoint 463 is 15
# Number of pixels in datapoint 464 is 16
# Number of pixels in datapoint 465 is 15
# Number of pixels in datapoint 466 is 15
# Number of pixels in datapoint 467 is 13
# Number of pixels in datapoint 468 is 15
# Number of pixels in datapoint 469 is 16
# Number of pixels in datapoint 470 is 15
# Number of pixels in datapoint 471 is 17
# Number of pixels in datapoint 472 is 16
# Number of pixels in datapoint 473 is 16
# Number of pixels in datapoint 474 is 15
# Number of pixels in datapoint 475 is 15
# Number of pixels in datapoint 476 is 16
# Number of pixels in datapoint 477 is 10
# Number of pixels in datapoint 478 is 15
# Number of pixels in datapoint 479 is 15
# Number of pixels in datapoint 480 is 14
# Number of pixels in datapoint 481 is 15
# Number of pixels in datapoint 482 is 15
# Number of pixels in datapoint 483 is 15
# Number of pixels in datapoint 484 is 11
# Number of pixels in datapoint 485 is 14
# Number of pixels in datapoint 486 is 14
# Number of pixels in datapoint 487 is 15
# Number of pixels in datapoint 488 is 12
# Number of pixels in datapoint 489 is 13
# Number of pixels in datapoint 490 is 16
# Number of pixels in datapoint 491 is 13
# Number of pixels in datapoint 492 is 15
# Number of pixels in datapoint 493 is 14
# Number of pixels in datapoint 494 is 15
# Number of pixels in datapoint 495 is 14
# Number of pixels in datapoint 496 is 12
# Number of pixels in datapoint 497 is 13
# Number of pixels in datapoint 498 is 15
# Number of pixels in datapoint 499 is 15
# Number of pixels in datapoint 500 is 11
# Number of pixels in datapoint 501 is 14
# Number of pixels in datapoint 502 is 17
# Number of pixels in datapoint 503 is 15
# Number of pixels in datapoint 504 is 16
# Number of pixels in datapoint 505 is 14
# Number of pixels in datapoint 506 is 13
# Number of pixels in datapoint 507 is 11
# Number of pixels in datapoint 508 is 13
# Number of pixels in datapoint 509 is 16
# Number of pixels in datapoint 510 is 16
# Number of pixels in datapoint 511 is 17
# Number of pixels in datapoint 512 is 13
# Number of pixels in datapoint 513 is 14
# Number of pixels in datapoint 514 is 15
# Number of pixels in datapoint 515 is 14
# Number of pixels in datapoint 516 is 15
# Number of pixels in datapoint 517 is 16
# Number of pixels in datapoint 518 is 16
# Number of pixels in datapoint 519 is 16
# Number of pixels in datapoint 520 is 15
# Number of pixels in datapoint 521 is 15
# Number of pixels in datapoint 522 is 13
# Number of pixels in datapoint 523 is 14
# Number of pixels in datapoint 524 is 13
# Number of pixels in datapoint 525 is 15
# Number of pixels in datapoint 526 is 15
# Number of pixels in datapoint 527 is 13
# Number of pixels in datapoint 528 is 15
# Number of pixels in datapoint 529 is 14
# Number of pixels in datapoint 530 is 16
# Number of pixels in datapoint 531 is 16
# Number of pixels in datapoint 532 is 13
# Number of pixels in datapoint 533 is 15
# Number of pixels in datapoint 534 is 13
# Number of pixels in datapoint 535 is 12
# Number of pixels in datapoint 536 is 16
# Number of pixels in datapoint 537 is 14
# Number of pixels in datapoint 538 is 13
# Number of pixels in datapoint 539 is 15
# Number of pixels in datapoint 540 is 14
# Number of pixels in datapoint 541 is 13
# Number of pixels in datapoint 542 is 17
# Number of pixels in datapoint 543 is 14
# Number of pixels in datapoint 544 is 16
# Number of pixels in datapoint 545 is 13
# Number of pixels in datapoint 546 is 16
# Number of pixels in datapoint 547 is 15
# Number of pixels in datapoint 548 is 13
# Number of pixels in datapoint 549 is 14
# Number of pixels in datapoint 550 is 14
# Number of pixels in datapoint 551 is 16
# Number of pixels in datapoint 552 is 16
# Number of pixels in datapoint 553 is 14
# Number of pixels in datapoint 554 is 13
# Number of pixels in datapoint 555 is 15
# Number of pixels in datapoint 556 is 14
# Number of pixels in datapoint 557 is 12
# Number of pixels in datapoint 558 is 12
# Number of pixels in datapoint 559 is 12
# Number of pixels in datapoint 560 is 14
# Number of pixels in datapoint 561 is 12
# Number of pixels in datapoint 562 is 16
# Number of pixels in datapoint 563 is 12
# Number of pixels in datapoint 564 is 17
# Number of pixels in datapoint 565 is 15
# Number of pixels in datapoint 566 is 15
# Number of pixels in datapoint 567 is 15
# Number of pixels in datapoint 568 is 16
# Number of pixels in datapoint 569 is 14
# Number of pixels in datapoint 570 is 14
# Number of pixels in datapoint 571 is 14
# Number of pixels in datapoint 572 is 14
# Number of pixels in datapoint 573 is 17
# Number of pixels in datapoint 574 is 13
# Number of pixels in datapoint 575 is 14
# Number of pixels in datapoint 576 is 11
# Number of pixels in datapoint 577 is 13
# Number of pixels in datapoint 578 is 15
# Number of pixels in datapoint 579 is 15
# Number of pixels in datapoint 580 is 13
# Number of pixels in datapoint 581 is 9
# Number of pixels in datapoint 582 is 15
# Number of pixels in datapoint 583 is 13
# Number of pixels in datapoint 584 is 14
# Number of pixels in datapoint 585 is 14
# Number of pixels in datapoint 586 is 16
# Number of pixels in datapoint 587 is 15
# Number of pixels in datapoint 588 is 13
# Number of pixels in datapoint 589 is 15
# Number of pixels in datapoint 590 is 14
# Number of pixels in datapoint 591 is 16
# Number of pixels in datapoint 592 is 15
# Number of pixels in datapoint 593 is 16
# Number of pixels in datapoint 594 is 15
# Number of pixels in datapoint 595 is 14
# Number of pixels in datapoint 596 is 14
# Number of pixels in datapoint 597 is 15
# Number of pixels in datapoint 598 is 15
# Number of pixels in datapoint 599 is 15
# Number of pixels in datapoint 600 is 14
# Number of pixels in datapoint 601 is 14
# Number of pixels in datapoint 602 is 16
# Number of pixels in datapoint 603 is 14
# Number of pixels in datapoint 604 is 14
# Number of pixels in datapoint 605 is 16
# Number of pixels in datapoint 606 is 17
# Number of pixels in datapoint 607 is 15
# Number of pixels in datapoint 608 is 16
# Number of pixels in datapoint 609 is 14
# Number of pixels in datapoint 610 is 13
# Number of pixels in datapoint 611 is 14
# Number of pixels in datapoint 612 is 14
# Number of pixels in datapoint 613 is 16
# Number of pixels in datapoint 614 is 16
# Number of pixels in datapoint 615 is 16
# Number of pixels in datapoint 616 is 15
# Number of pixels in datapoint 617 is 14
# Number of pixels in datapoint 618 is 17
# Number of pixels in datapoint 619 is 15
# Number of pixels in datapoint 620 is 13
# Number of pixels in datapoint 621 is 12
# Number of pixels in datapoint 622 is 15
# Number of pixels in datapoint 623 is 15
# Number of pixels in datapoint 624 is 14
# Number of pixels in datapoint 625 is 16
# Number of pixels in datapoint 626 is 14
# Number of pixels in datapoint 627 is 14
# Number of pixels in datapoint 628 is 14
# Number of pixels in datapoint 629 is 14
# Number of pixels in datapoint 630 is 16
# Number of pixels in datapoint 631 is 15
# Number of pixels in datapoint 632 is 15
# Number of pixels in datapoint 633 is 13
# Number of pixels in datapoint 634 is 16
# Number of pixels in datapoint 635 is 15
# Number of pixels in datapoint 636 is 13
# Number of pixels in datapoint 637 is 13
# Number of pixels in datapoint 638 is 14
# Number of pixels in datapoint 639 is 15
# Number of pixels in datapoint 640 is 13
# Number of pixels in datapoint 641 is 16
# Number of pixels in datapoint 642 is 13
# Number of pixels in datapoint 643 is 13
# Number of pixels in datapoint 644 is 13
# Number of pixels in datapoint 645 is 15
# Number of pixels in datapoint 646 is 11
# Number of pixels in datapoint 647 is 16
# Number of pixels in datapoint 648 is 15
# Number of pixels in datapoint 649 is 16
# Number of pixels in datapoint 650 is 13
# Number of pixels in datapoint 651 is 14
# Number of pixels in datapoint 652 is 12
# Number of pixels in datapoint 653 is 13
# Number of pixels in datapoint 654 is 17
# Number of pixels in datapoint 655 is 13
# Number of pixels in datapoint 656 is 13
# Number of pixels in datapoint 657 is 12
# Number of pixels in datapoint 658 is 16
# Number of pixels in datapoint 659 is 14
# Number of pixels in datapoint 660 is 15
# Number of pixels in datapoint 661 is 16
# Number of pixels in datapoint 662 is 13
# Number of pixels in datapoint 663 is 14
# Number of pixels in datapoint 664 is 16
# Number of pixels in datapoint 665 is 15
# Number of pixels in datapoint 666 is 14
# Number of pixels in datapoint 667 is 12
# Number of pixels in datapoint 668 is 16
# Number of pixels in datapoint 669 is 17
# Number of pixels in datapoint 670 is 12
# Number of pixels in datapoint 671 is 14
# Number of pixels in datapoint 672 is 13
# Number of pixels in datapoint 673 is 13
# Number of pixels in datapoint 674 is 16
# Number of pixels in datapoint 675 is 16
# Number of pixels in datapoint 676 is 13
# Number of pixels in datapoint 677 is 13
# Number of pixels in datapoint 678 is 14
# Number of pixels in datapoint 679 is 16
# Number of pixels in datapoint 680 is 15
# Number of pixels in datapoint 681 is 14
# Number of pixels in datapoint 682 is 15
# Number of pixels in datapoint 683 is 13
# Number of pixels in datapoint 684 is 14
# Number of pixels in datapoint 685 is 12
# Number of pixels in datapoint 686 is 16
# Number of pixels in datapoint 687 is 16
# Number of pixels in datapoint 688 is 11
# Number of pixels in datapoint 689 is 12
# Number of pixels in datapoint 690 is 13
# Number of pixels in datapoint 691 is 15
# Number of pixels in datapoint 692 is 15
# Number of pixels in datapoint 693 is 15
# Number of pixels in datapoint 694 is 15
# Number of pixels in datapoint 695 is 14
# Number of pixels in datapoint 696 is 15
# Number of pixels in datapoint 697 is 15
# Number of pixels in datapoint 698 is 12
# Number of pixels in datapoint 699 is 14
# Number of pixels in datapoint 700 is 14
# Number of pixels in datapoint 701 is 16
# Number of pixels in datapoint 702 is 15
# Number of pixels in datapoint 703 is 14
# Number of pixels in datapoint 704 is 15
# Number of pixels in datapoint 705 is 16
# Number of pixels in datapoint 706 is 16
# Number of pixels in datapoint 707 is 14
# Number of pixels in datapoint 708 is 17
# Number of pixels in datapoint 709 is 14
# Number of pixels in datapoint 710 is 15
# Number of pixels in datapoint 711 is 14
# Number of pixels in datapoint 712 is 17
# Number of pixels in datapoint 713 is 16
# Number of pixels in datapoint 714 is 17
# Number of pixels in datapoint 715 is 15
# Number of pixels in datapoint 716 is 16
# Number of pixels in datapoint 717 is 15
# Number of pixels in datapoint 718 is 16
# Number of pixels in datapoint 719 is 14
# Number of pixels in datapoint 720 is 15
# Number of pixels in datapoint 721 is 11
# Number of pixels in datapoint 722 is 16
# Number of pixels in datapoint 723 is 12
# Number of pixels in datapoint 724 is 15
# Number of pixels in datapoint 725 is 14
# Number of pixels in datapoint 726 is 16
# Number of pixels in datapoint 727 is 15
# Number of pixels in datapoint 728 is 13
# Number of pixels in datapoint 729 is 16
# Number of pixels in datapoint 730 is 15
# Number of pixels in datapoint 731 is 14
# Number of pixels in datapoint 732 is 14
# Number of pixels in datapoint 733 is 16
# Number of pixels in datapoint 734 is 12
# Number of pixels in datapoint 735 is 15
# Number of pixels in datapoint 736 is 13
# Number of pixels in datapoint 737 is 14
# Number of pixels in datapoint 738 is 13
# Number of pixels in datapoint 739 is 16
# Number of pixels in datapoint 740 is 14
# Number of pixels in datapoint 741 is 14
# Number of pixels in datapoint 742 is 15
# Number of pixels in datapoint 743 is 15
# Number of pixels in datapoint 744 is 15
# Number of pixels in datapoint 745 is 17
# Number of pixels in datapoint 746 is 15
# Number of pixels in datapoint 747 is 12
# Number of pixels in datapoint 748 is 13
# Number of pixels in datapoint 749 is 14
# Number of pixels in datapoint 750 is 13
# Number of pixels in datapoint 751 is 16
# Number of pixels in datapoint 752 is 15
# Number of pixels in datapoint 753 is 13
# Number of pixels in datapoint 754 is 14
# Number of pixels in datapoint 755 is 12
# Number of pixels in datapoint 756 is 15
# Number of pixels in datapoint 757 is 14
# Number of pixels in datapoint 758 is 16
# Number of pixels in datapoint 759 is 14
# Number of pixels in datapoint 760 is 13
# Number of pixels in datapoint 761 is 15
# Number of pixels in datapoint 762 is 16
# Number of pixels in datapoint 763 is 13
# Number of pixels in datapoint 764 is 15
# Number of pixels in datapoint 765 is 14
# Number of pixels in datapoint 766 is 13
# Number of pixels in datapoint 767 is 16
# Number of pixels in datapoint 768 is 15
# Number of pixels in datapoint 769 is 16
# Number of pixels in datapoint 770 is 15
# Number of pixels in datapoint 771 is 14
# Number of pixels in datapoint 772 is 12
# Number of pixels in datapoint 773 is 15
# Number of pixels in datapoint 774 is 15
# Number of pixels in datapoint 775 is 16
# Number of pixels in datapoint 776 is 15
# Number of pixels in datapoint 777 is 13
# Number of pixels in datapoint 778 is 12
# Number of pixels in datapoint 779 is 13
# Number of pixels in datapoint 780 is 13
# Number of pixels in datapoint 781 is 14
# Number of pixels in datapoint 782 is 14
# Number of pixels in datapoint 783 is 15
# Number of pixels in datapoint 784 is 13
# Number of pixels in datapoint 785 is 14
# Number of pixels in datapoint 786 is 15
# Number of pixels in datapoint 787 is 14
# Number of pixels in datapoint 788 is 12
# Number of pixels in datapoint 789 is 15
# Number of pixels in datapoint 790 is 16
# Number of pixels in datapoint 791 is 15
# Number of pixels in datapoint 792 is 16
# Number of pixels in datapoint 793 is 12
# Number of pixels in datapoint 794 is 15
# Number of pixels in datapoint 795 is 15
# Number of pixels in datapoint 796 is 15
# Number of pixels in datapoint 797 is 11
# Number of pixels in datapoint 798 is 15
# Number of pixels in datapoint 799 is 15
# Number of pixels in datapoint 800 is 15
# Number of pixels in datapoint 801 is 12
# Number of pixels in datapoint 802 is 14
# Number of pixels in datapoint 803 is 13
# Number of pixels in datapoint 804 is 14
# Number of pixels in datapoint 805 is 14
# Number of pixels in datapoint 806 is 16
# Number of pixels in datapoint 807 is 16
# Number of pixels in datapoint 808 is 15
# Number of pixels in datapoint 809 is 16
# Number of pixels in datapoint 810 is 13
# Number of pixels in datapoint 811 is 14
# Number of pixels in datapoint 812 is 16
# Number of pixels in datapoint 813 is 13
# Number of pixels in datapoint 814 is 14
# Number of pixels in datapoint 815 is 15
# Number of pixels in datapoint 816 is 16
# Number of pixels in datapoint 817 is 15
# Number of pixels in datapoint 818 is 15
# Number of pixels in datapoint 819 is 10
# Number of pixels in datapoint 820 is 14
# Number of pixels in datapoint 821 is 17
# Number of pixels in datapoint 822 is 14
# Number of pixels in datapoint 823 is 11
# Number of pixels in datapoint 824 is 14
# Number of pixels in datapoint 825 is 15
# Number of pixels in datapoint 826 is 15
# Number of pixels in datapoint 827 is 15
# Number of pixels in datapoint 828 is 14
# Number of pixels in datapoint 829 is 14
# Number of pixels in datapoint 830 is 17
# Number of pixels in datapoint 831 is 13
# Number of pixels in datapoint 832 is 14
# Number of pixels in datapoint 833 is 16
# Number of pixels in datapoint 834 is 14
# Number of pixels in datapoint 835 is 14
# Number of pixels in datapoint 836 is 16
# Number of pixels in datapoint 837 is 14
# Number of pixels in datapoint 838 is 16
# Number of pixels in datapoint 839 is 13
# Number of pixels in datapoint 840 is 15
# Number of pixels in datapoint 841 is 12
# Number of pixels in datapoint 842 is 12
# Number of pixels in datapoint 843 is 15
# Number of pixels in datapoint 844 is 13
# Number of pixels in datapoint 845 is 15
# Number of pixels in datapoint 846 is 14
# Number of pixels in datapoint 847 is 12
# Number of pixels in datapoint 848 is 15
# Number of pixels in datapoint 849 is 12
# Number of pixels in datapoint 850 is 15
# Number of pixels in datapoint 851 is 14
# Number of pixels in datapoint 852 is 17
# Number of pixels in datapoint 853 is 15
# Number of pixels in datapoint 854 is 12
# Number of pixels in datapoint 855 is 13
# Number of pixels in datapoint 856 is 10
# Number of pixels in datapoint 857 is 16
# Number of pixels in datapoint 858 is 16
# Number of pixels in datapoint 859 is 15
# Number of pixels in datapoint 860 is 15
# Number of pixels in datapoint 861 is 12
# Number of pixels in datapoint 862 is 15
# Number of pixels in datapoint 863 is 15
# Number of pixels in datapoint 864 is 16
# Number of pixels in datapoint 865 is 16
# Number of pixels in datapoint 866 is 14
# Number of pixels in datapoint 867 is 15
# Number of pixels in datapoint 868 is 14
# Number of pixels in datapoint 869 is 15
# Number of pixels in datapoint 870 is 17
# Number of pixels in datapoint 871 is 16
# Number of pixels in datapoint 872 is 16
# Number of pixels in datapoint 873 is 12
# Number of pixels in datapoint 874 is 13
# Number of pixels in datapoint 875 is 14
# Number of pixels in datapoint 876 is 16
# Number of pixels in datapoint 877 is 15
# Number of pixels in datapoint 878 is 16
# Number of pixels in datapoint 879 is 15
# Number of pixels in datapoint 880 is 15
# Number of pixels in datapoint 881 is 15
# Number of pixels in datapoint 882 is 13
# Number of pixels in datapoint 883 is 14
# Number of pixels in datapoint 884 is 17
# Number of pixels in datapoint 885 is 13
# Number of pixels in datapoint 886 is 12
# Number of pixels in datapoint 887 is 16
# Number of pixels in datapoint 888 is 12
# Number of pixels in datapoint 889 is 14
# Number of pixels in datapoint 890 is 15
# Number of pixels in datapoint 891 is 15
# Number of pixels in datapoint 892 is 12
# Number of pixels in datapoint 893 is 14
# Number of pixels in datapoint 894 is 16
# Number of pixels in datapoint 895 is 13
# Number of pixels in datapoint 896 is 14
# Number of pixels in datapoint 897 is 17
# Number of pixels in datapoint 898 is 14
# Number of pixels in datapoint 899 is 13
# Number of pixels in datapoint 900 is 16
# Number of pixels in datapoint 901 is 14
# Number of pixels in datapoint 902 is 16
# Number of pixels in datapoint 903 is 15
# Number of pixels in datapoint 904 is 15
# Number of pixels in datapoint 905 is 14
# Number of pixels in datapoint 906 is 17
# Number of pixels in datapoint 907 is 14
# Number of pixels in datapoint 908 is 11
# Number of pixels in datapoint 909 is 15
# Number of pixels in datapoint 910 is 15
# Number of pixels in datapoint 911 is 16
# Number of pixels in datapoint 912 is 14
# Number of pixels in datapoint 913 is 16
# Number of pixels in datapoint 914 is 16
# Number of pixels in datapoint 915 is 15
# Number of pixels in datapoint 916 is 15
# Number of pixels in datapoint 917 is 13
# Number of pixels in datapoint 918 is 16
# Number of pixels in datapoint 919 is 16
# Number of pixels in datapoint 920 is 14
# Number of pixels in datapoint 921 is 16
# Number of pixels in datapoint 922 is 14
# Number of pixels in datapoint 923 is 13
# Number of pixels in datapoint 924 is 16
# Number of pixels in datapoint 925 is 16
# Number of pixels in datapoint 926 is 16
# Number of pixels in datapoint 927 is 15
# Number of pixels in datapoint 928 is 15
# Number of pixels in datapoint 929 is 16
# Number of pixels in datapoint 930 is 15
# Number of pixels in datapoint 931 is 13
# Number of pixels in datapoint 932 is 15
# Number of pixels in datapoint 933 is 15
# Number of pixels in datapoint 934 is 12
# Number of pixels in datapoint 935 is 10
# Number of pixels in datapoint 936 is 14
# Number of pixels in datapoint 937 is 16
# Number of pixels in datapoint 938 is 14
# Number of pixels in datapoint 939 is 15
# Number of pixels in datapoint 940 is 13
# Number of pixels in datapoint 941 is 13
# Number of pixels in datapoint 942 is 15
# Number of pixels in datapoint 943 is 16
# Number of pixels in datapoint 944 is 16
# Number of pixels in datapoint 945 is 16
# Number of pixels in datapoint 946 is 15
# Number of pixels in datapoint 947 is 15
# Number of pixels in datapoint 948 is 15
# Number of pixels in datapoint 949 is 13
# Number of pixels in datapoint 950 is 14
# Number of pixels in datapoint 951 is 15
# Number of pixels in datapoint 952 is 15
# Number of pixels in datapoint 953 is 13
# Number of pixels in datapoint 954 is 16
# Number of pixels in datapoint 955 is 15
# Number of pixels in datapoint 956 is 13
# Number of pixels in datapoint 957 is 14
# Number of pixels in datapoint 958 is 14
# Number of pixels in datapoint 959 is 16
# Number of pixels in datapoint 960 is 13
# Number of pixels in datapoint 961 is 14
# Number of pixels in datapoint 962 is 15
# Number of pixels in datapoint 963 is 17
# Number of pixels in datapoint 964 is 15
# Number of pixels in datapoint 965 is 15
# Number of pixels in datapoint 966 is 15
# Number of pixels in datapoint 967 is 12
# Number of pixels in datapoint 968 is 14
# Number of pixels in datapoint 969 is 16
# Number of pixels in datapoint 970 is 16
# Number of pixels in datapoint 971 is 14
# Number of pixels in datapoint 972 is 16
# Number of pixels in datapoint 973 is 16
# Number of pixels in datapoint 974 is 14
# Number of pixels in datapoint 975 is 13
# Number of pixels in datapoint 976 is 15
# Number of pixels in datapoint 977 is 15
# Number of pixels in datapoint 978 is 12
# Number of pixels in datapoint 979 is 13
# Number of pixels in datapoint 980 is 15
# Number of pixels in datapoint 981 is 16
# Number of pixels in datapoint 982 is 12
# Number of pixels in datapoint 983 is 16
# Number of pixels in datapoint 984 is 13
# Number of pixels in datapoint 985 is 12
# Number of pixels in datapoint 986 is 15
# Number of pixels in datapoint 987 is 16
# Number of pixels in datapoint 988 is 13
# Number of pixels in datapoint 989 is 14
# Number of pixels in datapoint 990 is 15
# Number of pixels in datapoint 991 is 15
# Number of pixels in datapoint 992 is 15
# Number of pixels in datapoint 993 is 14
# Number of pixels in datapoint 994 is 15
# Number of pixels in datapoint 995 is 13
# Number of pixels in datapoint 996 is 14
# Number of pixels in datapoint 997 is 15
# Number of pixels in datapoint 998 is 13
# Number of pixels in datapoint 999 is 16
# Number of pixels in datapoint 1000 is 15
# Number of pixels in datapoint 1001 is 14
# Number of pixels in datapoint 1002 is 10
# Number of pixels in datapoint 1003 is 15
# Number of pixels in datapoint 1004 is 16
# Number of pixels in datapoint 1005 is 13
# Number of pixels in datapoint 1006 is 12
# Number of pixels in datapoint 1007 is 16
# Number of pixels in datapoint 1008 is 15
# Number of pixels in datapoint 1009 is 14
# Number of pixels in datapoint 1010 is 13
# Number of pixels in datapoint 1011 is 15
# Number of pixels in datapoint 1012 is 16
# Number of pixels in datapoint 1013 is 13
# Number of pixels in datapoint 1014 is 15
# Number of pixels in datapoint 1015 is 15
# Number of pixels in datapoint 1016 is 15
# Number of pixels in datapoint 1017 is 16
# Number of pixels in datapoint 1018 is 16
# Number of pixels in datapoint 1019 is 15
# Number of pixels in datapoint 1020 is 15
# Number of pixels in datapoint 1021 is 15
# Number of pixels in datapoint 1022 is 16
# Number of pixels in datapoint 1023 is 15
# Number of pixels in datapoint 1024 is 13
# Number of pixels in datapoint 1025 is 14
# Number of pixels in datapoint 1026 is 12
# Number of pixels in datapoint 1027 is 12
# Number of pixels in datapoint 1028 is 14
# Number of pixels in datapoint 1029 is 16
# Number of pixels in datapoint 1030 is 15
# Number of pixels in datapoint 1031 is 16
# Number of pixels in datapoint 1032 is 13
# Number of pixels in datapoint 1033 is 16
# Number of pixels in datapoint 1034 is 14
# Number of pixels in datapoint 1035 is 14
# Number of pixels in datapoint 1036 is 14
# Number of pixels in datapoint 1037 is 15
# Number of pixels in datapoint 1038 is 15
# Number of pixels in datapoint 1039 is 16
# Number of pixels in datapoint 1040 is 12
# Number of pixels in datapoint 1041 is 14
# Number of pixels in datapoint 1042 is 16
# Number of pixels in datapoint 1043 is 12
# Number of pixels in datapoint 1044 is 12
# Number of pixels in datapoint 1045 is 12
# Number of pixels in datapoint 1046 is 12
# Number of pixels in datapoint 1047 is 15
# Number of pixels in datapoint 1048 is 13
# Number of pixels in datapoint 1049 is 15
# Number of pixels in datapoint 1050 is 15
# Number of pixels in datapoint 1051 is 14
# Number of pixels in datapoint 1052 is 13
# Number of pixels in datapoint 1053 is 14
# Number of pixels in datapoint 1054 is 13
# Number of pixels in datapoint 1055 is 14
# Number of pixels in datapoint 1056 is 14
# Number of pixels in datapoint 1057 is 14
# Number of pixels in datapoint 1058 is 15
# Number of pixels in datapoint 1059 is 12
# Number of pixels in datapoint 1060 is 16
# Number of pixels in datapoint 1061 is 15
# Number of pixels in datapoint 1062 is 12
# Number of pixels in datapoint 1063 is 15
# Number of pixels in datapoint 1064 is 14
# Number of pixels in datapoint 1065 is 13
# Number of pixels in datapoint 1066 is 14
# Number of pixels in datapoint 1067 is 15
# Number of pixels in datapoint 1068 is 14
# Number of pixels in datapoint 1069 is 15
# Number of pixels in datapoint 1070 is 15
# Number of pixels in datapoint 1071 is 15
# Number of pixels in datapoint 1072 is 15
# Number of pixels in datapoint 1073 is 15
# Number of pixels in datapoint 1074 is 15
# Number of pixels in datapoint 1075 is 14
# Number of pixels in datapoint 1076 is 17
# Number of pixels in datapoint 1077 is 14
# Number of pixels in datapoint 1078 is 14
# Number of pixels in datapoint 1079 is 15
# Number of pixels in datapoint 1080 is 12
# Number of pixels in datapoint 1081 is 14
# Number of pixels in datapoint 1082 is 14
# Number of pixels in datapoint 1083 is 13
# Number of pixels in datapoint 1084 is 15
# Number of pixels in datapoint 1085 is 15
# Number of pixels in datapoint 1086 is 16
# Number of pixels in datapoint 1087 is 15
# Number of pixels in datapoint 1088 is 14
# Number of pixels in datapoint 1089 is 14
# Number of pixels in datapoint 1090 is 15
# Number of pixels in datapoint 1091 is 16
# Number of pixels in datapoint 1092 is 13
# Number of pixels in datapoint 1093 is 13
# Number of pixels in datapoint 1094 is 15
# Number of pixels in datapoint 1095 is 14
# Number of pixels in datapoint 1096 is 16
# Number of pixels in datapoint 1097 is 14
# Number of pixels in datapoint 1098 is 16
# Number of pixels in datapoint 1099 is 15
# Number of pixels in datapoint 1100 is 15
# Number of pixels in datapoint 1101 is 14
# Number of pixels in datapoint 1102 is 14
# Number of pixels in datapoint 1103 is 15
# Number of pixels in datapoint 1104 is 14
# Number of pixels in datapoint 1105 is 14
# Number of pixels in datapoint 1106 is 16
# Number of pixels in datapoint 1107 is 14
# Number of pixels in datapoint 1108 is 16
# Number of pixels in datapoint 1109 is 14
# Number of pixels in datapoint 1110 is 13
# Number of pixels in datapoint 1111 is 14
# Number of pixels in datapoint 1112 is 17
# Number of pixels in datapoint 1113 is 15
# Number of pixels in datapoint 1114 is 15
# Number of pixels in datapoint 1115 is 14
# Number of pixels in datapoint 1116 is 14
# Number of pixels in datapoint 1117 is 16
# Number of pixels in datapoint 1118 is 14
# Number of pixels in datapoint 1119 is 14
# Number of pixels in datapoint 1120 is 14
# Number of pixels in datapoint 1121 is 15
# Number of pixels in datapoint 1122 is 15
# Number of pixels in datapoint 1123 is 15
# Number of pixels in datapoint 1124 is 14
# Number of pixels in datapoint 1125 is 15
# Number of pixels in datapoint 1126 is 15
# Number of pixels in datapoint 1127 is 14
# Number of pixels in datapoint 1128 is 14
# Number of pixels in datapoint 1129 is 13
# Number of pixels in datapoint 1130 is 14
# Number of pixels in datapoint 1131 is 17
# Number of pixels in datapoint 1132 is 15
# Number of pixels in datapoint 1133 is 15
# Number of pixels in datapoint 1134 is 14
# Number of pixels in datapoint 1135 is 10
# Number of pixels in datapoint 1136 is 13
# Number of pixels in datapoint 1137 is 14
# Number of pixels in datapoint 1138 is 15
# Number of pixels in datapoint 1139 is 16
# Number of pixels in datapoint 1140 is 15
# Number of pixels in datapoint 1141 is 12
# Number of pixels in datapoint 1142 is 13
# Number of pixels in datapoint 1143 is 14
# Number of pixels in datapoint 1144 is 15
# Number of pixels in datapoint 1145 is 13
# Number of pixels in datapoint 1146 is 12
# Number of pixels in datapoint 1147 is 15
# Number of pixels in datapoint 1148 is 16
# Number of pixels in datapoint 1149 is 12
# Number of pixels in datapoint 1150 is 14
# Number of pixels in datapoint 1151 is 16
# Number of pixels in datapoint 1152 is 17
# Number of pixels in datapoint 1153 is 14
# Number of pixels in datapoint 1154 is 15
# Number of pixels in datapoint 1155 is 15
# Number of pixels in datapoint 1156 is 14
# Number of pixels in datapoint 1157 is 13
# Number of pixels in datapoint 1158 is 15
# Number of pixels in datapoint 1159 is 14
# Number of pixels in datapoint 1160 is 16
# Number of pixels in datapoint 1161 is 15
# Number of pixels in datapoint 1162 is 13
# Number of pixels in datapoint 1163 is 16
# Number of pixels in datapoint 1164 is 15
# Number of pixels in datapoint 1165 is 14
# Number of pixels in datapoint 1166 is 14
# Number of pixels in datapoint 1167 is 11
# Number of pixels in datapoint 1168 is 15
# Number of pixels in datapoint 1169 is 14
# Number of pixels in datapoint 1170 is 8
# Number of pixels in datapoint 1171 is 15
# Number of pixels in datapoint 1172 is 12
# Number of pixels in datapoint 1173 is 16
# Number of pixels in datapoint 1174 is 13
# Number of pixels in datapoint 1175 is 16
# Number of pixels in datapoint 1176 is 14
# Number of pixels in datapoint 1177 is 15
# Number of pixels in datapoint 1178 is 14
# Number of pixels in datapoint 1179 is 10
# Number of pixels in datapoint 1180 is 15
# Number of pixels in datapoint 1181 is 14
# Number of pixels in datapoint 1182 is 15
# Number of pixels in datapoint 1183 is 14
# Number of pixels in datapoint 1184 is 16
# Number of pixels in datapoint 1185 is 14
# Number of pixels in datapoint 1186 is 15
# Number of pixels in datapoint 1187 is 12
# Number of pixels in datapoint 1188 is 13
# Number of pixels in datapoint 1189 is 14
# Number of pixels in datapoint 1190 is 12
# Number of pixels in datapoint 1191 is 16
# Number of pixels in datapoint 1192 is 15
# Number of pixels in datapoint 1193 is 14
# Number of pixels in datapoint 1194 is 12
# Number of pixels in datapoint 1195 is 17
# Number of pixels in datapoint 1196 is 14
# Number of pixels in datapoint 1197 is 13
# Number of pixels in datapoint 1198 is 15
# Number of pixels in datapoint 1199 is 14
# Number of pixels in datapoint 1200 is 14
# Number of pixels in datapoint 1201 is 16
# Number of pixels in datapoint 1202 is 15
# Number of pixels in datapoint 1203 is 14
# Number of pixels in datapoint 1204 is 16
# Number of pixels in datapoint 1205 is 14
# Number of pixels in datapoint 1206 is 14
# Number of pixels in datapoint 1207 is 13
# Number of pixels in datapoint 1208 is 15
# Number of pixels in datapoint 1209 is 15
# Number of pixels in datapoint 1210 is 16
# Number of pixels in datapoint 1211 is 13
# Number of pixels in datapoint 1212 is 17
# Number of pixels in datapoint 1213 is 15
# Number of pixels in datapoint 1214 is 9
# Number of pixels in datapoint 1215 is 15
# Number of pixels in datapoint 1216 is 15
# Number of pixels in datapoint 1217 is 14
# Number of pixels in datapoint 1218 is 9
# Number of pixels in datapoint 1219 is 15
# Number of pixels in datapoint 1220 is 14
# Number of pixels in datapoint 1221 is 15
# Number of pixels in datapoint 1222 is 13
# Number of pixels in datapoint 1223 is 15
# Number of pixels in datapoint 1224 is 16
# Number of pixels in datapoint 1225 is 16
# Number of pixels in datapoint 1226 is 15
# Number of pixels in datapoint 1227 is 12
# Number of pixels in datapoint 1228 is 15
# Number of pixels in datapoint 1229 is 15
# Number of pixels in datapoint 1230 is 14
# Number of pixels in datapoint 1231 is 13
# Number of pixels in datapoint 1232 is 16
# Number of pixels in datapoint 1233 is 17
# Number of pixels in datapoint 1234 is 15
# Number of pixels in datapoint 1235 is 14
# Number of pixels in datapoint 1236 is 14
# Number of pixels in datapoint 1237 is 15
# Number of pixels in datapoint 1238 is 15
# Number of pixels in datapoint 1239 is 16
# Number of pixels in datapoint 1240 is 13
# Number of pixels in datapoint 1241 is 15
# Number of pixels in datapoint 1242 is 17
# Number of pixels in datapoint 1243 is 16
# Number of pixels in datapoint 1244 is 14
# Number of pixels in datapoint 1245 is 14
# Number of pixels in datapoint 1246 is 15
# Number of pixels in datapoint 1247 is 16
# Number of pixels in datapoint 1248 is 15
# Number of pixels in datapoint 1249 is 15
# Number of pixels in datapoint 1250 is 14
# Number of pixels in datapoint 1251 is 15
# Number of pixels in datapoint 1252 is 14
# Number of pixels in datapoint 1253 is 15
# Number of pixels in datapoint 1254 is 16
# Number of pixels in datapoint 1255 is 14
# Number of pixels in datapoint 1256 is 15
# Number of pixels in datapoint 1257 is 15
# Number of pixels in datapoint 1258 is 14
# Number of pixels in datapoint 1259 is 14
# Number of pixels in datapoint 1260 is 14
# Number of pixels in datapoint 1261 is 16
# Number of pixels in datapoint 1262 is 14
# Number of pixels in datapoint 1263 is 15
# Number of pixels in datapoint 1264 is 14
# Number of pixels in datapoint 1265 is 13
# Number of pixels in datapoint 1266 is 14
# Number of pixels in datapoint 1267 is 15
# Number of pixels in datapoint 1268 is 15
# Number of pixels in datapoint 1269 is 15
# Number of pixels in datapoint 1270 is 14
# Number of pixels in datapoint 1271 is 16
# Number of pixels in datapoint 1272 is 15
# Number of pixels in datapoint 1273 is 15
# Number of pixels in datapoint 1274 is 11
# Number of pixels in datapoint 1275 is 14
# Number of pixels in datapoint 1276 is 15
# Number of pixels in datapoint 1277 is 13
# Number of pixels in datapoint 1278 is 13
# Number of pixels in datapoint 1279 is 16
# Number of pixels in datapoint 1280 is 14
# Number of pixels in datapoint 1281 is 16
# Number of pixels in datapoint 1282 is 15
# Number of pixels in datapoint 1283 is 12
# Number of pixels in datapoint 1284 is 16
# Number of pixels in datapoint 1285 is 16
# Number of pixels in datapoint 1286 is 14
# Number of pixels in datapoint 1287 is 16
# Number of pixels in datapoint 1288 is 12
# Number of pixels in datapoint 1289 is 12
# Number of pixels in datapoint 1290 is 14
# Number of pixels in datapoint 1291 is 14
# Number of pixels in datapoint 1292 is 15
# Number of pixels in datapoint 1293 is 14
# Number of pixels in datapoint 1294 is 12
# Number of pixels in datapoint 1295 is 13
# Number of pixels in datapoint 1296 is 13
# Number of pixels in datapoint 1297 is 17
# Number of pixels in datapoint 1298 is 10
# Number of pixels in datapoint 1299 is 14
# Number of pixels in datapoint 1300 is 14
# Number of pixels in datapoint 1301 is 11
# Number of pixels in datapoint 1302 is 15
# Number of pixels in datapoint 1303 is 15
# Number of pixels in datapoint 1304 is 16
# Number of pixels in datapoint 1305 is 16
# Number of pixels in datapoint 1306 is 14
# Number of pixels in datapoint 1307 is 16
# Number of pixels in datapoint 1308 is 14
# Number of pixels in datapoint 1309 is 16
# Number of pixels in datapoint 1310 is 13
# Number of pixels in datapoint 1311 is 15
# Number of pixels in datapoint 1312 is 16
# Number of pixels in datapoint 1313 is 12
# Number of pixels in datapoint 1314 is 12
# Number of pixels in datapoint 1315 is 15
# Number of pixels in datapoint 1316 is 12
# Number of pixels in datapoint 1317 is 16
# Number of pixels in datapoint 1318 is 16
# Number of pixels in datapoint 1319 is 14
# Number of pixels in datapoint 1320 is 14
# Number of pixels in datapoint 1321 is 12
# Number of pixels in datapoint 1322 is 15
# Number of pixels in datapoint 1323 is 17
# Number of pixels in datapoint 1324 is 14
# Number of pixels in datapoint 1325 is 12
# Number of pixels in datapoint 1326 is 12
# Number of pixels in datapoint 1327 is 14
# Number of pixels in datapoint 1328 is 12
# Number of pixels in datapoint 1329 is 14
# Number of pixels in datapoint 1330 is 14
# Number of pixels in datapoint 1331 is 13
# Number of pixels in datapoint 1332 is 14
# Number of pixels in datapoint 1333 is 14
# Number of pixels in datapoint 1334 is 15
# Number of pixels in datapoint 1335 is 13
# Number of pixels in datapoint 1336 is 15
# Number of pixels in datapoint 1337 is 16
# Number of pixels in datapoint 1338 is 15
# Number of pixels in datapoint 1339 is 14
# Number of pixels in datapoint 1340 is 16
# Number of pixels in datapoint 1341 is 14
# Number of pixels in datapoint 1342 is 13
# Number of pixels in datapoint 1343 is 15
# Number of pixels in datapoint 1344 is 15
# Number of pixels in datapoint 1345 is 15
# Number of pixels in datapoint 1346 is 13
# Number of pixels in datapoint 1347 is 12
# Number of pixels in datapoint 1348 is 14
# Number of pixels in datapoint 1349 is 16
# Number of pixels in datapoint 1350 is 15
# Number of pixels in datapoint 1351 is 14
# Number of pixels in datapoint 1352 is 15
# Number of pixels in datapoint 1353 is 16
# Number of pixels in datapoint 1354 is 11
# Number of pixels in datapoint 1355 is 15
# Number of pixels in datapoint 1356 is 14
# Number of pixels in datapoint 1357 is 15
# Number of pixels in datapoint 1358 is 16
# Number of pixels in datapoint 1359 is 13
# Number of pixels in datapoint 1360 is 14
# Number of pixels in datapoint 1361 is 13
# Number of pixels in datapoint 1362 is 13
# Number of pixels in datapoint 1363 is 14
# Number of pixels in datapoint 1364 is 14
# Number of pixels in datapoint 1365 is 14
# Number of pixels in datapoint 1366 is 15
# Number of pixels in datapoint 1367 is 15
# Number of pixels in datapoint 1368 is 14
# Number of pixels in datapoint 1369 is 17
# Number of pixels in datapoint 1370 is 14
# Number of pixels in datapoint 1371 is 15
# Number of pixels in datapoint 1372 is 13
# Number of pixels in datapoint 1373 is 16
# Number of pixels in datapoint 1374 is 15
# Number of pixels in datapoint 1375 is 16
# Number of pixels in datapoint 1376 is 15
# Number of pixels in datapoint 1377 is 13
# Number of pixels in datapoint 1378 is 15
# Number of pixels in datapoint 1379 is 16
# Number of pixels in datapoint 1380 is 14
# Number of pixels in datapoint 1381 is 13
# Number of pixels in datapoint 1382 is 13
# Number of pixels in datapoint 1383 is 14
# Number of pixels in datapoint 1384 is 15
# Number of pixels in datapoint 1385 is 15
# Number of pixels in datapoint 1386 is 15
# Number of pixels in datapoint 1387 is 14
# Number of pixels in datapoint 1388 is 15
# Number of pixels in datapoint 1389 is 14
# Number of pixels in datapoint 1390 is 14
# Number of pixels in datapoint 1391 is 15
# Number of pixels in datapoint 1392 is 17
# Number of pixels in datapoint 1393 is 16
# Number of pixels in datapoint 1394 is 14
# Number of pixels in datapoint 1395 is 16
# Number of pixels in datapoint 1396 is 15
# Number of pixels in datapoint 1397 is 15
# Number of pixels in datapoint 1398 is 13
# Number of pixels in datapoint 1399 is 11
# Number of pixels in datapoint 1400 is 15
# Number of pixels in datapoint 1401 is 15
# Number of pixels in datapoint 1402 is 13
# Number of pixels in datapoint 1403 is 16
# Number of pixels in datapoint 1404 is 14
# Number of pixels in datapoint 1405 is 15
# Number of pixels in datapoint 1406 is 14
# Number of pixels in datapoint 1407 is 13
# Number of pixels in datapoint 1408 is 14
# Number of pixels in datapoint 1409 is 16
# Number of pixels in datapoint 1410 is 15
# Number of pixels in datapoint 1411 is 14
# Number of pixels in datapoint 1412 is 13
# Number of pixels in datapoint 1413 is 15
# Number of pixels in datapoint 1414 is 16
# Number of pixels in datapoint 1415 is 13
# Number of pixels in datapoint 1416 is 14
# Number of pixels in datapoint 1417 is 14
# Number of pixels in datapoint 1418 is 15
# Number of pixels in datapoint 1419 is 14
# Number of pixels in datapoint 1420 is 15
# Number of pixels in datapoint 1421 is 14
# Number of pixels in datapoint 1422 is 12
# Number of pixels in datapoint 1423 is 14
# Number of pixels in datapoint 1424 is 15
# Number of pixels in datapoint 1425 is 13
# Number of pixels in datapoint 1426 is 13
# Number of pixels in datapoint 1427 is 13
# Number of pixels in datapoint 1428 is 15
# Number of pixels in datapoint 1429 is 16
# Number of pixels in datapoint 1430 is 11
# Number of pixels in datapoint 1431 is 15
# Number of pixels in datapoint 1432 is 16
# Number of pixels in datapoint 1433 is 14
# Number of pixels in datapoint 1434 is 14
# Number of pixels in datapoint 1435 is 15
# Number of pixels in datapoint 1436 is 15
# Image for digit 0
# (360,)
# (1437,)

# %% [markdown]
# *Wow, I can't believe we just created a KNN Classifier for multiple classes - but can't we make it better?*
#
# Yes, we saw above that our classifier didn't work perfectly. Let's explore that issue a little further by turning the $K$ and random split knobs
#
# ### Problem 3: Improving KNN on Digits - 20 Points
#
# 3.1 Determine which classes are most often confused (from our confusion matrix above), inspect some examples of these digits (using the `view_digit` function in our Numbers class), and write a brief (4 - 5 sentences) description of why you think these particular numbers may be misclassified. (10 pts)
#
# 3.2 Explore the influence of the number of nearest neighbors (i.e. try changing our K). Plot the relationship between K and accuracy, and write a brief (4 - 5 sentences) description of how this factor impacts our accuracy. To mitigate the effect of randomness from the split, you have to run the evaluation multiple times and report the mean accuracy. Make sure the runs for different Ks are done on the same splits. (5 pts)
#
# 3.3 Explore the influence of the train / test split of our data (i.e. copy our Numbers class into Numbers2 below and try changing the split for our dataset). Plot the relationship between the split % and accuracy, and write a brief (4 - 5 sentences) description of its impact. (5 pts)
#
# You can complete the `NumbersKnobs` class and use it as you see fit. But it's only necessary for 3.3

# %%
#BEGIN 3.1a
#TODO: Print out problem class images

#END 3.1a

# %% [markdown]
# #### 3.1b
# TODO: Write description of mis-classification

# %%
#BEGIN 3.2a
#TODO: Run evaluation for different K and plot K vs Accuracy

#END 3.2a

# %% [markdown]
# #### 3.2b
# TODO: Write of effect of K on classifier accuracy

# %%
class NumbersKnobs(Numbers):
    """ Inherits from Numbers, so feel free to use methods from Numbers
    """

    def __init__(self, k=5, train_ratio=0.8):
        #load data from sklearn
        self._k = k
        self.train_ratio = train_ratio
        
        data = sklearn.datasets.load_digits()
        features = data["data"]
        labels = data["target"]
        features = features.reshape(features.shape[0], -1)

        #BEGIN Workspace 3.3a
        self.train_x = np.array(None) # A 2D np.array of training examples, REPLACE
        self.train_y = np.array(None) # A 1D np.array of training answers, REPLACE
        self.test_x = np.array(None) # A 2D np.array of testing examples, REPLACE
        self.test_y = np.array(None) # A 1D np.array of testing answers, REPLACE
        self.classifier = None # KNNClassifier, REPLACE
        
        # TODO: - Divide our dataset into Train and Test datasets (80/20 split),
        #        replacing the variables above
        #       - Initialize the classifier
        #TODO: Divide our dataset into Train and Test datasets (using trainPercentage), replacing the variables above
        #HINT: You should be able to mostly copy your own work from the original Numbers class
        #END Workspace 3.3a

# %%
#BEGIN Workspace 3.3b
#TODO: analyze the effect of split ratio
k = 5
repetitions = 5 # Feel free to increase it
split_ratios = np.array([0.5, 0.6, 0.7])
results = np.zeros((len(split_ratios),repetitions))
for i, s in enumerate(split_ratios):
    print(s ,end =": ")
    for j in range(repetitions):
        print(j, end=",")
        numbers = NumbersKnobs(k=k, train_ratio=s)
        results[i,j] = None # TODO get accuracy of classification
    print("")
# Add title axis labels to the plot
plt.plot(split_ratios, results.mean(1))

#END Workspace 3.3b

# %% [markdown]
# #### 3.3b
# TODO: Write of effect of varying the split ratio, ultimately, you can run the classification several times for a fixed K and different split ratios

# %% [markdown]
# ### Problem 4 : Improving KNN on MNIST using WeightedKNN (30 pts)
# Complete the `WeightedKNNClassifier` class to perform the weighted KNN classification.
# The Weighted KNN classifier assigns weights to the nearest-neighbor training examples proportional to the inverse-distance from the training example to the query point. Classification is performed by summing the weights associated with each class and predicting the class with the highest weighted-majority vote. Mathematically we might describe the weighted-vote for a class $c$ as
#
# $$
# \textrm{Weighted-Vote}(c)(x) = \sum_{i \in {\cal N}_K(x)} I(y_i \in c) \times \frac{1}{\|{\bf x}_i - {\bf x}\|}
# $$
# where ${\cal N}_K(x)$ is the set of the closest $k$ neighbors to $x$
#
#
# 4.1 Complete the `fit` method in a similar way to `KNNClassifier` (5 pts)
#
# 4.2 Complete `majority_vote`: it's certainly possible that a query point could be distance $0$ away from some training example. If this happens your implementation should handle it and return the appropriate class label. (5 pts)
#
# 4.3 Complete `predict` (5 pts)
#
# 4.4 Compete `confusion_matrix` and `accuracy` methods (5 pts)
#
# 4.5 Compare `KNNClassifier` and `WeightedKNNClassifier` for multiple $K$, make sure that for each run both classifers are fitted using the same train/test split. You can execute multiple runs to mitigate the split randomness. Report for which K you get the best accuracy for each classifier and the best overall classifier. (10 pts)

# %%
class WeightedKNNClassifier:
    """
    Class to store data for regression problems 
    """
    def __init__(self, k):
        """
        Creates a kNN instance
        :param k: The number of nearest points to consider in classification
        """
        
        # Import and build the BallTree on training features 
        self._k = k
        self._model = None
        self._y = None
        
        # Boolean flag indicating whether to do distance weighting (if you want to make it versatile)
        
    def fit(self, features, labels):
        
        # BEGIN Workspace 4.1
        self._model = None # REPLACE
        self._y = np.array(None) #  REPLACE

        #END Workspace 4.1

        # Should be used to map set of classes to {0,1,..C-1} where C is the number of classes
        classes = list(set(list(labels)))
        self.label_to_index = dict(zip(sorted(classes), range(len(classes))))
        self.index_to_label = dict(zip(range(len(classes)), sorted(classes)))
        return self



    def majority_vote(self, neighbor_indices, neighbor_distances=None):
        """
        Given indices of nearest neighbors in training set, return the majority label. 
        Break ties by considering 1 fewer neighbor until a clear winner is found. 

        :param neighbor_indices: The indices of the K nearest neighbors in self.X_train 
        :param neighbor_distances: Corresponding distances from query point to K nearest neighbors. 
        """
        
        
        # YOUR CODE HERE
        #BEGIN Workspace 4.2
        labels = [] #REPLACE
        #END Workspace 4.2
        
        return labels
    
    def predict(self, features):
        """
        Given an np.array of query points, return y_hat, an np.array of predictions

        :param features: an (m x p) dimension np.array of points to predict labels for
        """
        labels = None
        # YOUR CODE HERE
        #BEGIN Workspace 4.3
        #TODO: predict labels
        #END Workspace 4.3
        return labels
    def confusion_matrix(self, features_test, labels_test):
        """
        Generate a confusion matrix for the given test set
        PARAMETERS
        testX - an np.array of feature vectors of test points
        testY - the corresponding correct classifications of our test set
        RETURN
        C - an N*N np.array of counts, where N is the number of classes in our classifier
        """
        c_matrix = np.array(None)
        #BEGIN Workspace 4.4.a
        #TODO: Run classification for the test set, compare to test answers, and add counts to matrix
            
        #END Workspace 4.4.a
    
        return c_matrix
    
    def accuracy(self, features_test, labels_test):
        """
        Generate an accuracy score for the classifier based on the confusion matrix
        PARAMETERS
        C - an np.array of counts
        RETURN
        score - an accuracy score
        """
        score = 0
        #BEGIN Workspace 4.4.b
        #TODO: Compute accuracy of the classification of features_test
        c_matrix = self.confusion_matrix(features_test, labels_test)
        
        #END Workspace 4.4.b
        return score

# %%
class NumbersWeighted(NumbersKnobs):
    def __init__(self, k=5, train_ratio=0.8):
        super(NumbersWeighted, self).__init__(k, train_ratio)
        self.classifier = WeightedKNNClassifier(k=self._k)

# %%
#BEGIN Workspace 4.5
#TODO: Run multiple comparisons
repetitions = 10
ks = [1, 2, 4, 5, 6, 32, 50] # Add more
results_simple = np.zeros((len(ks),repetitions))
results_weighted = np.zeros((len(ks),repetitions))

for i, k in enumerate(ks):
    print(k,end =": ")
    for j in range(repetitions):
        print(j, end=",")
        numbers = NumbersWeighted(k=k)
        results_weighted[i,j] = # TODO get accuracy
        numbers.classifier = KNNClassifier(k=numbers._k)
        results_simple[i,j] =  #TODO get accuracy
    print("")

#TODO Average results over multiple runs and report best classifier
    
#END Workspace 4.5

# %% [markdown]
# #### 4.5
# TODO: Report best results per classifier and overall performance.

# %% [markdown]
# #### Bonus (5 Points)
# __4.6 Is `WeightedKNNClassifier` a consistent classifier? why or why not?__

# %% [markdown]
# *4.6 bonus response here*
